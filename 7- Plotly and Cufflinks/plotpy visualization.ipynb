# %%
# pip install plotly cufflinks

# %%
import pandas as pd
import numpy as np

# %%
from plotly import __version__

print(__version__)
# Out:
# 5.9.0

# %%
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning:
#
# Blowfish has been deprecated

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df= pd.DataFrame(np.random.randn(100,4), columns='A B C D'.split())
df
# Out:
#            A         B         C         D
# 0  -0.558427  0.625755 -0.335117  0.506919
# 1   0.724864 -0.668531 -1.097477  0.982047
# 2   0.033900  0.100830  0.204558 -0.555888
# 3   0.441977  1.907240  0.459348 -1.516091
# 4   1.298840  0.968211  2.090242 -0.568702
# ..       ...       ...       ...       ...
# 95 -0.509031  1.064903  0.437466 -0.144706
# 96  0.267148  0.198166 -1.347457  1.193460
# 97 -0.075131 -0.686632 -2.444418  0.386477
# 98 -0.779230  0.380376 -0.283710 -1.944852
# 99 -0.064565  0.852322 -0.127852  0.277100
#
# [100 rows x 4 columns]

# %%
df2= pd.DataFrame({'Categories':['A', "B", 'C'], 'Values': [ 32, 43, 50]})
df2
# Out:
#   Categories  Values
# 0          A      32
# 1          B      43
# 2          C      50

# %%
df.iplot()
# Out:
# <div>                            <div id="9d52f1b5-996a-465d-83bd-aebf795a1d51" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot( kind= "scatter", x="A", y='B') # this is the default scatter in which the points are connected with line
# Out:
# <div>                            <div id="9cfcd9ae-642d-4553-b675-329215695d0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot( kind= "scatter", x="A", y='B', mode= 'markers')
# Out:
# <div>                            <div id="b1b35121-de84-4ca1-a0e7-dae807b9391e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot( kind= "bar", x="Categories", y='Values', mode= 'markers')
# Out:
# <div>                            <div id="99acab99-7175-48c9-90c2-2a2406e08f4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind= "box")
# Out:
# <div>                            <div id="0fc7b1b8-7734-447a-baa3-f6b622ffe8b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3= pd.DataFrame({'x': [1,2,3,4,5], 'y': [10,20,30,20,10], '2':[500, 400, 300, 200, 180]})
df3
# Out:
#    x   y    2
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  20  200
# 4  5  10  180

# %%
df3.iplot(kind= "surface")
# Out:
# <div>                            <div id="1b2dd3ce-97b9-4459-ba31-b90b79886fdb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['A'].iplot(kind= 'hist')
# Out:
# <div>                            <div id="44523a22-ae36-4a03-bc3b-feb836fea8c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Spread plot is used when we are comparing two columns for example stock price of two companies

# %%
df[['A', 'B']].iplot(kind='spread')
# Out:
# C:\Users\user\AppData\Roaming\Python\Python311\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#
# C:\Users\user\AppData\Roaming\Python\Python311\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
# <div>                            <div id="f7e481bc-7499-44a6-a317-3b6463b578ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# This is similar to pairplot of the seaborn library and for this all the columns should be numerical

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="f559538c-1c3d-4f6e-89b6-f4079a95e211" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
